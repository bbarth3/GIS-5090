# %%
import arcpy

# %%
from arcpy.sa import *
arcpy.env.workspace = r"C:\Users\brend_000\Documents\ArcGIS\Projects\GIS 5090\GIS 5090 - Project 2"

# %% [markdown]
# ## Problem 1

# %%
rasterlist = arcpy.ListRasters()
rasterlist
# Out:
# ['compbands.tif', 'falsecolor.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B1.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B10.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B11.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B2.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B3.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B4.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B5.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B6.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B7.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B8.tif', 'LC08_L1TP_046028_20200908_20200918_01_T1_B9.tif', 'rastermean.tif']

# %%
#Using Composite Bands (Links to an external site.), create a 3 band R-G-B image from bands 2, 3, and 4 
comp = arcpy.CompositeBands_management("LC08_L1TP_046028_20200908_20200918_01_T1_B1.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B2.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B3.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B4.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B5.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B6.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B7.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B8.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B9.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B10.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B11.tif", 
                                       "compbands.tif")

# %%
comp
# Out:
# <Result 'C:\\Users\\brend_000\\Documents\\ArcGIS\\Projects\\GIS 5090\\GIS 5090 - Project 2\\compbands.tif'>

# %%
#Calculate the NDVI of the scene (Links to an external site.) (10 points)
NDVI_raster = arcpy.ia.NDVI("compbands.tif", 5, 4)
NDVI_raster
# Out:
# C:\Users\BREND_~1\AppData\Local\Temp\ArcGISProTemp8964\x9dfab89d_4543_45c9_9364_12af8b0a6bf6y0.afr

# %%
#Calculate the SAVI of the scene (Links to an external site.) (10 points)
SAVI_raster = arcpy.sa.NDVI("compbands.tif",5,4)
SAVI_raster
# Out:
# C:\Users\BREND_~1\AppData\Local\Temp\ArcGISProTemp8964\xdd2bd9f1_a7d0_4705_a36f_28deff2d8452y0.afr

# %%
#Using Composite Bands (Links to an external site.), create a false color infrared image from bands 3, 4, 5 
falsecolor = arcpy.CompositeBands_management("LC08_L1TP_046028_20200908_20200918_01_T1_B3.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B4.tif;LC08_L1TP_046028_20200908_20200918_01_T1_B5.tif",
                                            "falsecolor.tif")
falsecolor
# Out:
# <Result 'C:\\Users\\brend_000\\Documents\\ArcGIS\\Projects\\GIS 5090\\GIS 5090 - Project 2\\falsecolor.tif'>

# %% [markdown]
# ## Problem 2

# %%
#Import arcpy 
#Check out the Spatial extension
import arcpy
from arcpy.sa import *
arcpy.CheckOutExtension("Spatial")
# Out:
# 'CheckedOut'

# %%
#Define the workspace 
#Create a rasterlist
arcpy.env.workspace = r'C:\Users\brend_000\Documents\ArcGIS\Projects\GIS 5090\GIS 5090 - Project 2\Landsat_p114r75'
rasterlist = arcpy.ListRasters()
rasterlist
# Out:
# ['p114r075_7t20000501_z50_nn10.tif', 'p114r075_7t20000501_z50_nn20.tif', 'p114r075_7t20000501_z50_nn30.tif', 'p114r075_7t20000501_z50_nn40.tif', 'workmean']

# %%
#Calculate the mean
inRaster01 = "p114r075_7t20000501_z50_nn10.tif"
inRaster02 = "p114r075_7t20000501_z50_nn20.tif"
inRaster03 = "p114r075_7t20000501_z50_nn30.tif"
inRaster04 = "p114r075_7t20000501_z50_nn40.tif"

rastermean = CellStatistics([inRaster01, inRaster02, inRaster03, inRaster04], "MEAN")
rastermean.save(r"C:\Users\brend_000\Documents\ArcGIS\Projects\GIS 5090\GIS 5090 - Project 2\rastermean.tif")

# %%
rastermean
# Out:
# C:\Users\brend_000\Documents\ArcGIS\Projects\GIS 5090\GIS 5090 - Project 2\rastermean.tif
